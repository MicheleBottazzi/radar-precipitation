# %%
import numpy as np
import rasterio
#from affine import Affine
from shapely.geometry import shape
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = rasterio.open('201909092120.tiff')

# %%
dataset
# Out:
# <open DatasetReader name='201909092120.tiff' mode='r'>

# %%
msk = dataset.read(1)

# %%
msk
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(msk)
plt.show()

# %%
msk[msk==255]=0

# %%
msk[msk<10]=0
msk[msk>=10]=1
msk[msk==0]=255

# %%
plt.imshow(msk)
plt.show()

# %%
plt.imshow(msk)
plt.show()

# %%
image = np.ones((150, 250), dtype=rasterio.ubyte) * 127

with rasterio.open(
        'test-tiff.tiff', 'w', crs=dataset.crs,
        driver='GTiff', width=msk8.shape[1], height=msk.shape[0], count=1,
        dtype=msk8.dtype) as dst:
    dst.write(msk, indexes=1)

# %%
dts = rasterio.open('test-tiff.tiff')

# %%
plt.imshow(msk)
plt.show()
